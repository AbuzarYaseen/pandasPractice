# %%
# When multiple series are combined then this becomes a data frame.
# Data frame can be created from a dictionary and a list.

# %%
import numpy as np
import pandas as pd

# %%
#Creating Data Frame

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# Selection and Indexing of Columns

# %%
df2["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[["City", "Name"]]
# Out:
#        City   Name
# 0  New York   John
# 1     Paris   Anna
# 2    Berlin  Peter
# 3    London  Linda

# %%
# Creating a new column
df2["Designation"] = ["Engineer", "Doctor", "Plumber", "Pilot"]

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000      Doctor
# 2  Peter   29    Berlin   62000     Plumber
# 3  Linda   42    London   85000       Pilot

# %%
# Removing a column
# Below is the snapshoot, column is still in the main data
df2.drop("Designation", axis=1)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000    Engineer
# 1   Anna   34     Paris   70000      Doctor
# 2  Peter   29    Berlin   62000     Plumber
# 3  Linda   42    London   85000       Pilot

# %%
# For deleting completly
df2.drop("Designation",axis=1,inplace=True)

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.drop(["Salary", "City"],axis=1)
# Out:
#     Name  Age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# Removing Rows same as removing columns just gave axis 0
df2.drop(0,axis=0)
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %%
df2.drop([1,2],axis=0)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 3  Linda   42    London   85000

# %%
# Selecting Rows
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
# Selecting both rows and columns

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df.loc[[2,3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %%
# Conditional Selection

# %%
# Only wants to see those people whose age is above 30

# %%
df2[df2["Age"] > 30 ]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df2[(df2["Age"] > 30) & (df2["City"] == "Paris")]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
