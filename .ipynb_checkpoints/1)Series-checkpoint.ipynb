# %% [markdown]
# **A series is a one dimentional labled array capable of holding any data type. The axis lables are collectively called index.**
# **Series are vertical and arrays are horizontal.**

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'c', 'c']
myList = [10, 20, 30]
myArr = np.array([10, 20, 30])
dic = {1:10, 2:20, 3:30}

# %%
pd.Series(myList) #Series can be created from list
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(myList, index=labels)
# Out:
# a    10
# c    20
# c    30
# dtype: int64

# %%
pd.Series(myArr, index=labels) #Series can alse be created from arrays
# Out:
# a    10
# c    20
# c    30
# dtype: int64

# %% [markdown]
# **Series can alse be created from dictionaries, creating from dictionary indexs are also setted from the keys of dictionary.**

# %%
pd.Series(dic)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
